# %% [markdown]
# # Stock Market Analysis on Car Companies
#
# I will be analyzing stock data related to a few car companies, from Jan 1 2012 to Jan 1 2017. This project is mainly just to challenge my skills with matplotlib, pandas, and numpy. Don't infer financial trading advice from the analysis we do here!
#
# The purpose of this assignment is to view different correlations and movements of Tesla, Ford, and GM stock data.

# %%
# Import libraries for the challenge 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Use pandas_datareader to obtain the historical stock information from Jan 1, 2012 to Jan 1, 2017
import pandas_datareader
import datetime
import pandas_datareader.data as web

# %%
# Create start and end date using datetime
start = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2017, 1, 1)

# %%
# Use Yahoo Finance Api from the web to pull in data 
# start with Tesla 
tesla = web.DataReader('TSLA', 'yahoo', start, end)

# %%
tesla.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2012-01-03  29.500000  27.650000  28.940001  28.080000   928100  28.080000
# 2012-01-04  28.670000  27.500000  28.209999  27.709999   630100  27.709999
# 2012-01-05  27.930000  26.850000  27.760000  27.120001  1005500  27.120001
# 2012-01-06  27.790001  26.410000  27.200001  26.910000   986300  26.910000
# 2012-01-09  27.490000  26.120001  27.000000  27.250000   897000  27.250000

# %%
# Pull in Ford Stock data using the Yahoo Finance API from the web to pull in data 
ford = web.DataReader('F', 'yahoo', start, end)
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.687118
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.804530
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   8.004824
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   8.087703
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   8.149862

# %%
# Pull in GM Stock data using the Yahoo Finance API from the web to pull in data 
gm = web.DataReader('GM', 'yahoo', start, end)
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.103352
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.179853
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  16.960161
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.533915
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.472712

# %% [markdown]
# ## Visualize the Data
# ### Create a linear lot of all the car companies stocks price over time

# %%
# create the plot for all 3 car companies
tesla['Open'].plot(label='Telsa', figsize=(16,8), title='Opening Price')
ford['Open'].plot(label='Ford')
gm['Open'].plot(label='GM')
plt.legend()

# %% [markdown]
# ### Plot the Volume of stock traded each day

# %%
# create a plot representing the amount of volume for each car company in one graph. 
tesla['Volume'].plot(label='Tesla', figsize=(16, 8), title='Volume Traded')
ford['Volume'].plot(label='Ford')
gm['Volume'].plot(label='GM')
plt.legend()

# %% [markdown]
# **Interesting, looks like ford had a really big spike where in late 2013. What was the date of this maximum trading volume for ford?**
# **What happened that day?**

# %%
#Find the exact date of the max volume for ford in late 2013
ford['Volume'].argmax()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# Timestamp('2013-12-18 00:00:00')

# %% [markdown]
# After, googling the date for Ford there was an investor meeting where they announced that they would aggresively push new product launches into the next year and that may cut profits for the 2014.
#
# Sources:
#     - https://money.cnn.com/2013/12/18/news/companies/ford-profit/index.html

# %% [markdown]
# ### Total Traded Amount

# %% [markdown]
# **The Open Price Time Series Visualization makes Tesla look like its always been much more valuable as a company than GM and Ford. But to really understand this we would need to look at the total market cap of the company, not just the stock price. Unfortunately our current data doesn't have that information of total units of stock present. But what we can do as a simple calcualtion to try to represent total money traded would be to multply the Volume column by the Open price. Remember that this still isn't the actual Market Cap, its just a visual representation of the total amount of money being traded around using the time series. (e.g. 100 units of stock at \$10 each versus 100000 units of stock at $1 each)**

# %% [markdown]
# I will create a new column for each dataframe called "Total Traded" which is the Open Price multiplied by the Volume Traded.

# %%
# Create the Total Traded arugment
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']

# %%
# Plot the Total Traded against the time index 
tesla['Total Traded'].plot(label='Tesla', figsize=(16, 8))
ford['Total Traded'].plot(label='Ford')
gm['Total Traded'].plot(label='GM')
plt.legend()
plt.ylabel('Total Traded')
plt.title('Tesla, Ford, and GM Total Traded Amount')
# Out:
# Text(0.5, 1.0, 'Tesla, Ford, and GM Total Traded Amount')

# %% [markdown]
# **Interesting, looks like there was huge amount of money traded for Tesla somewhere in early 2014. What date was that and what happened?**

# %%
# Find out the day of the max Total Traded amount for Tesla.
tesla['Total Traded'].argmax()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# Timestamp('2014-02-25 00:00:00')

# %% [markdown]
# After further investigation of the date and tesla stock I found out information that a Morgan Stanley analyst gave Tesla a higher rating based off stronger than expected profits.
# Sources:
#     - https://money.cnn.com/2014/02/25/investing/tesla-record-high/
#     - https://blogs.wsj.com/moneybeat/2014/02/25/tesla-shares-surge-on-morgan-stanley-report/

# %% [markdown]
# ### Ploting MA(Moving Averages)

# %%
# Plot out the MA50 and MA200 for GM
gm['50 MA'] = gm['Open'].rolling(50).mean()
gm['200 MA'] = gm['Open'].rolling(200).mean()
gm[['Open', '50 MA', '200 MA']].plot(label='GM', figsize=(16,8))
plt.ylabel('Price')
plt.title('GM Stock')
# Out:
# Text(0.5, 1.0, 'GM Stock')

# %% [markdown]
# **Lets see if there is a relationship between these stocks, since they are all realted to the car industry.I will use a scatter plot matrix from pandas plotting to see all the stock's opening price.**
#
# ### Scatter Plot Matrix to Compare the Companies Stock

# %%
# Import scatter_matrix library 
from pandas.plotting import scatter_matrix

# %%
# Create a new df to add all 3 car companies together 
car_comp = pd.concat([tesla['Open'], ford['Open'], gm['Open']], axis= 1)

# %%
car_comp.head()
# Out:
#                  Open   Open       Open
# Date
# 2012-01-03  28.940001  11.00  20.830000
# 2012-01-04  28.209999  11.15  21.049999
# 2012-01-05  27.760000  11.33  21.100000
# 2012-01-06  27.200001  11.74  22.260000
# 2012-01-09  27.000000  11.83  23.200001

# %%
# change the column index to represent each car company 
car_comp.columns= ["Tesla Open", "Ford Open", 'GM Open']

# %%
car_comp.head()
# Out:
#             Tesla Open  Ford Open    GM Open
# Date
# 2012-01-03   28.940001      11.00  20.830000
# 2012-01-04   28.209999      11.15  21.049999
# 2012-01-05   27.760000      11.33  21.100000
# 2012-01-06   27.200001      11.74  22.260000
# 2012-01-09   27.000000      11.83  23.200001

# %%
#create the scatter maxtrix plot for all 3 car companies to see if there are any correlations
# add alpha to view concentration in ranges 
# increase the number of bars in the histogram via hist_kwds
scatter_matrix(car_comp, figsize= (10,10), alpha=0.3, hist_kwds={'bins': 50});

# %% [markdown]
# **Findings:** As you can see there is a greater correlation between Ford and GM over the time period. This is because we have noticed that there stock relative to one another are very similar on the contray Tesla stock has less correlation as the stock has increased in value drastically over the same time period.

# %% [markdown]
# ## Creating a Candle Stick Visualization Chart
#
# I will create a Candle Stick chart for Tesla, Ford, and GM in Jan 2012

# %%
# Import new library 
import mplfinance as mpf
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

# %%
#create candle stick plots and categorize up and down days. 
tesla_plt = tesla[['Open', 'High', 'Low', 'Close']].loc['2012-01']
mc = mpf.make_marketcolors(up='g', down='r')
s = mpf.make_mpf_style(marketcolors=mc)
mpf.plot(tesla_plt, type= 'candle', style=s)

# %%
#create candle stick plots and categorize up and down days. 
ford_plt = ford[['Open', 'High', 'Low', 'Close']].loc['2012-01']
mc = mpf.make_marketcolors(up='g', down='r')
s = mpf.make_mpf_style(marketcolors=mc)
mpf.plot(ford_plt, type= 'candle', style=s)

# %%
#create candle stick plots and categorize up and down days. 
gm_plt = gm[['Open', 'High', 'Low', 'Close']].loc['2012-01']
mc = mpf.make_marketcolors(up='g', down='r')
s = mpf.make_mpf_style(marketcolors=mc)
mpf.plot(gm_plt, type= 'candle', style=s)

# %% [markdown]
# **These charts give us another way of looking at the stock price over a period of time and you can see how the candlestick chart plots the open and close range.**

# %% [markdown]
# ## Financial Analysis
#
# I will use a few key financial calculations to find out more about the companies stock.
#
# ### Daily Percentage Change
#
# Daily percentage change is defined by the following formula:

# %% [markdown]
# $ r_t = \frac{p_t}{p_{t-1}} -1$

# %% [markdown]
# This defines r_t (return at time t) as equal to the price at time t divided by the price at time t-1 (the previous day) minus 1. Basically this just informs you of your percent gain (or loss) if you bought the stock on day and then sold it the next day. While this isn't necessarily helpful for attempting to predict future values of the stock, its very helpful in analyzing the volatility of the stock. If daily returns have a wide distribution, the stock is more volatile from one day to the next.

# %% [markdown]
# I will be using 2 methods of finding the percentage change from the close price column.

# %%
# Method 1: Using shift
# tesla['returns'] = (tesla['Close'] / tesla['Close'].shift(1) ) - 1

#Method 2: Using the built in pct_change method
tesla['returns'] = tesla['Close'].pct_change(1)
ford['returns'] = ford['Close'].pct_change(1)
gm['returns'] = gm['Close'].pct_change(1)

#pc_change period is 1 for one day of change %

# %%
#check work there should be a NaN value for the first date as the pct_change occurs at close
tesla['returns']
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04   -0.013177
# 2012-01-05   -0.021292
# 2012-01-06   -0.007743
# 2012-01-09    0.012635
#                 ...
# 2016-12-23    0.023459
# 2016-12-27    0.029015
# 2016-12-28    0.000957
# 2016-12-29   -0.023027
# 2016-12-30   -0.004611
# Name: returns, Length: 1258, dtype: float64

# %% [markdown]
# ## Compare the Companies Daily Return
#
# ### Compare the Volatilty of Each Stock
# Lets find out which stock is the most "Volatile"? (as judged by the variance in the daily returns)

# %%
# Add all companies returns to a histogram plot and show the comparison 
tesla['returns'].hist(bins=100, label='Tesla', figsize=(10,8), alpha=0.4)
ford['returns'].hist(bins=100, label="Ford", figsize=(10,8), alpha=0.4)
gm['returns'].hist(bins=100, label="GM", figsize=(10,8), alpha=0.4)
plt.legend()

# %% [markdown]
# **We can view that Tesla has a wider range of volatility incomparison to Ford and GM. It is also noticed in the candle stick plots above. Ford and GM are relatively more stable stocks.**

# %%
# Plotting using a KDE instead of a histogram for another point of view.
tesla['returns'].plot(kind='kde', label='Tesla', figsize=(10,8))
ford['returns'].plot(kind='kde', label='Ford', figsize=(10,8))
gm['returns'].plot(kind='kde', label='GM', figsize=(10,8))
plt.legend()

# %% [markdown]
# **Ford has less volatility from the other 2 car companies and Tesla is the widest which means it's more volatile as mentioned before.**

# %%
# Use a Box Plot to view the car companies returns
#concat the 3 returns of the car companies and plot
box_df = pd.concat([tesla['returns'], ford['returns'], gm['returns']], axis=1)
box_df.columns = ['Tesla Returns', 'Ford Returns', 'GM Returns']
box_df.plot(kind='box', figsize=(8,11))

# %% [markdown]
# ### Comparing Daily Returns between Stocks
#
# I will create a scatter matrix plot to see the correlation between each of the stocks daily returns.

# %%
#create a scatter matrix plot to see the difference in daily returns 
scatter_matrix(box_df,figsize=(8,8),alpha=0.2,hist_kwds={'bins':50});

# %% [markdown]
# **Tesla could be treated more as technology company rather than a car company by the market. While Ford and GM look like they have a stronger relationship.**

# %%
# Plot Ford and GM to see their relationship 
box_df.plot(kind='scatter', x='Ford Returns', y='GM Returns', alpha = 0.5, figsize=(8,8))

# %% [markdown]
# Ford and GM have a strong corraltion to one another.

# %% [markdown]
# ## Cumulative Daily Returns
#
# It is proven that Tesla has the most wide ranging daily returns from the plots given above.
#
# Now looking at daily cumulative returns, the question we are trying to answer is the following, if I invested $1 in the company at the beginning of the time series, how much would is be worth today? This is different than just the stock price at the current day, because it will take into account the daily returns. Keep in mind, our simple calculation here won't take into account stocks that give back a dividend.

# %% [markdown]
# **Daily Return** : Daily return is the profit/loss made by the stock compared to the previous day. A value above one indicates profit, similarly a value below one indicates loss. It is also expressed in percentage to convey the information better. (When expressed as percentage, if the value is above 0, the stock had give you profit else loss).

# %% [markdown]
# **Cumulative Return**: While daily returns are useful, it doesn't give the investor a immediate insight into the gains he had made till date, especially if the stock is very volatile. Cumulative return is computed relative to the day investment is made.  If cumulative return is above one, you are making profits else you are in loss.

# %% [markdown]
# The formula for a cumulative daily return is:
#
# $ i_i = (1+r_t) * i_{t-1} $
#
# Here we can see we are just multiplying our previous investment at i at t-1 by 1+our percent returns. Pandas makes this very simple to calculate with its cumprod() method. Using something in the following manner:
#
#     df[daily_cumulative_return] = ( 1 + df[pct_daily_return] ).cumprod()

# %%
# Create a cumulative daily return column for each car company's DataFrame. 
tesla['Cumulative Return'] = (1 + tesla['returns']).cumprod()

# %%
tesla.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2012-01-03  29.500000  27.650000  28.940001  28.080000   928100  28.080000
# 2012-01-04  28.670000  27.500000  28.209999  27.709999   630100  27.709999
# 2012-01-05  27.930000  26.850000  27.760000  27.120001  1005500  27.120001
# 2012-01-06  27.790001  26.410000  27.200001  26.910000   986300  26.910000
# 2012-01-09  27.490000  26.120001  27.000000  27.250000   897000  27.250000
#
#             Total Traded   returns  Cumulative Return
# Date
# 2012-01-03  2.685921e+07       NaN                NaN
# 2012-01-04  1.777512e+07 -0.013177           0.986823
# 2012-01-05  2.791268e+07 -0.021292           0.965812
# 2012-01-06  2.682736e+07 -0.007743           0.958333
# 2012-01-09  2.421900e+07  0.012635           0.970442

# %%
ford['Cumulative Return'] = (1 + ford['returns']).cumprod()
gm['Cumulative Return'] = (1 + gm['returns']).cumprod()
